# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravR96/Face-Recognition-using-Deep-Learning/blob/main/LBP_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import pickle
import random

from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, BatchNormalization, LSTM, Bidirectional
from tensorflow.keras.optimizers import RMSprop, SGD
from keras.preprocessing.image import ImageDataGenerator, img_to_array
from keras import backend as K
from keras import regularizers, callbacks
from random import randint
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from google.colab.patches import cv2_imshow

# %%
def train_model():
    path = '/content/drive/MyDrive/orl_lbp/'

        # 1-hot encoding
    a = np.array([i for i in range(43)])
    classes = np.zeros((a.size, a.max() + 1))
    classes[np.arange(a.size), a] = 1

    train_array = []
    test_array = []
    dir_array = []

    for dir in os.listdir(path):
        #i1 = np.random.choice(range(0,9), 4)
        #i1 = np.random.choice(range(0,9), 5)
        i1 = np.random.choice(range(0,9), 6)
        for i1, img in enumerate(sorted(os.listdir(path + dir))):
            image = cv2.imread(path + dir + '/' + img, 0)
            image = image[:, :, np.newaxis]
            if i1:
                train_array.append((image, classes[os.listdir(path).index(dir)]))
            elif not(i1):
                test_array.append((image, classes[os.listdir(path).index(dir)]))


        dir_array.append(dir)

    input_shape = (112, 92, 1)

    model = Sequential()
    # convolutional layer 16 windows/filters of 3x3
    model.add(Conv2D(16, kernel_size=(3,3),
                     activation='relu',
                     kernel_regularizer=regularizers.l2(0.),
                     activity_regularizer=regularizers.l2(0.),
                     input_shape=input_shape))

    # max of each 2x2 block
    #model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # normalization
    model.add(BatchNormalization())

    # avoid overfitting
    #model.add(Dropout(0.25))
    model.add(Dropout(0.50))

    model.add(Conv2D(32, kernel_size=(4,4),
                     activation='relu',
                     kernel_regularizer=regularizers.l2(0.),
                     activity_regularizer=regularizers.l2(0.)))

    #model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(BatchNormalization())
    #model.add(Dropout(0.25))
    model.add(Dropout(0.50))
    
    # flatten for final layers
    model.add(Flatten())

    # fully-connected layer
    model.add(Dense(512, activation='relu',
                    kernel_regularizer=regularizers.l2(0.),
                    activity_regularizer=regularizers.l2(0.)))

    #model.add(Dropout(0.25))
    model.add(Dropout(0.50))

    model.add(Dense(43, activation='softmax'))
    #model.add(Dense(43, activation='relu', kernel_regularizer=regularizers.l2(0.), activity_regularizer=regularizers.l2(0.))) # very low accuracy


    model.summary()
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'],
                  run_eagerly=None)

    train_images, train_labels = np.array([t[0] for t in train_array]), np.array([t[1] for t in train_array])
    test_images, test_labels = np.array([t[0] for t in test_array]), np.array([t[1] for t in test_array])

    history = model.fit(train_images, train_labels,
                        batch_size=16,
                        epochs=30,
                        verbose=2,
                        validation_data=(test_images, test_labels))
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model train vs validation loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

    loss_train = history.history['accuracy']
    loss_val = history.history['val_accuracy']
    epochs = range(0,30)
    plt.plot(epochs, loss_train, 'g', label='Training accuracy')
    plt.plot(epochs, loss_val, 'b', label='validation accuracy')
    plt.title('Training and Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')  
    plt.legend()
    plt.show()

    with open('face_recognition_model.pkl', 'wb') as f:
        pickle.dump(model, f)

    return test_images, test_labels, classes, dir_array
def evaluate_model(test_images, test_labels, classes, dir_array):
    with open('face_recognition_model.pkl', 'rb') as f:
        model = pickle.load(f)

    score = model.evaluate(test_images, test_labels, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

# evaluate test images added in the orl database
    imageindex = 9

    pathsorin1 = '/content/drive/MyDrive/orl_lbp/sorin_LBP/lbp_' + str(imageindex) + '.pgm'
    sorin1 = cv2.imread(pathsorin1, cv2.IMREAD_UNCHANGED)
    cv2_imshow(sorin1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    sorin1 = cv2.resize(sorin1, (92, 112))
    sorin1 = sorin1[:, :, np.newaxis]

    imageindex = 9

    pathandreea1 = '/content/drive/MyDrive/orl_lbp/andreea_LBP/lbp_' + str(imageindex) + '.pgm'
    andreea1 = cv2.imread(pathandreea1, cv2.IMREAD_UNCHANGED)
    cv2_imshow(andreea1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    andreea1 = cv2.resize(andreea1, (92, 112))
    andreea1 = andreea1[:, :, np.newaxis]

    imageindex = 9

    pathalex1 = '/content/drive/MyDrive/orl_lbp/alex_LBP/lbp_' + str(imageindex) + '.pgm'
    alex1 = cv2.imread(pathalex1, cv2.IMREAD_UNCHANGED)
    cv2_imshow(alex1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    alex1 = cv2.resize(alex1, (92, 112))
    alex1 = alex1[:, :, np.newaxis]

    people_test_image = np.array([sorin1, andreea1, alex1])

    [prediction1, prediction2, prediction3] = model.predict(people_test_image)

    a = max([(c, cosine_similarity([prediction1], [c])) for c in classes], key=lambda t:t[1])
    b = max([(c, cosine_similarity([prediction2], [c])) for c in classes], key=lambda t:t[1])
    c = max([(c, cosine_similarity([prediction3], [c])) for c in classes], key=lambda t:t[1])

    print(dir_array[list(a[0]).index(1)])
    print(dir_array[list(b[0]).index(1)])
    print(dir_array[list(c[0]).index(1)])

ti, tl, c, d = train_model()
evaluate_model(ti, tl, c, d)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 110, 90, 16)       160
#
#  max_pooling2d_8 (MaxPooling  (None, 55, 45, 16)       0
#  2D)
#
#  batch_normalization_10 (Bat  (None, 55, 45, 16)       64
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 55, 45, 16)        0
#
#  conv2d_11 (Conv2D)          (None, 52, 42, 32)        8224
#
#  max_pooling2d_9 (MaxPooling  (None, 26, 21, 32)       0
#  2D)
#
#  batch_normalization_11 (Bat  (None, 26, 21, 32)       128
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 26, 21, 32)        0
#
#  flatten_5 (Flatten)         (None, 17472)             0
#
#  dense_10 (Dense)            (None, 512)               8946176
#
#  dropout_17 (Dropout)        (None, 512)               0
#
#  dense_11 (Dense)            (None, 43)                22059
#
# =================================================================
# Total params: 8,976,811
# Trainable params: 8,976,715
# Non-trainable params: 96
# _________________________________________________________________
# Epoch 1/30
# 25/25 - 7s - loss: 4.9641 - accuracy: 0.1550 - val_loss: 37.6183 - val_accuracy: 0.0698 - 7s/epoch - 279ms/step
# Epoch 2/30
# 25/25 - 6s - loss: 0.6377 - accuracy: 0.8243 - val_loss: 23.7607 - val_accuracy: 0.0698 - 6s/epoch - 236ms/step
# Epoch 3/30
# 25/25 - 6s - loss: 0.2331 - accuracy: 0.9147 - val_loss: 16.0909 - val_accuracy: 0.1395 - 6s/epoch - 235ms/step
# Epoch 4/30
# 25/25 - 6s - loss: 0.1055 - accuracy: 0.9664 - val_loss: 8.6000 - val_accuracy: 0.2326 - 6s/epoch - 235ms/step
# Epoch 5/30
# 25/25 - 6s - loss: 0.0884 - accuracy: 0.9716 - val_loss: 2.1786 - val_accuracy: 0.5349 - 6s/epoch - 235ms/step
# Epoch 6/30
# 25/25 - 6s - loss: 0.0660 - accuracy: 0.9793 - val_loss: 1.3742 - val_accuracy: 0.6047 - 6s/epoch - 237ms/step
# Epoch 7/30
# 25/25 - 6s - loss: 0.0548 - accuracy: 0.9871 - val_loss: 0.7761 - val_accuracy: 0.7907 - 6s/epoch - 237ms/step
# Epoch 8/30
# 25/25 - 6s - loss: 0.0482 - accuracy: 0.9845 - val_loss: 0.5201 - val_accuracy: 0.8837 - 6s/epoch - 240ms/step
# Epoch 9/30
# 25/25 - 6s - loss: 0.0370 - accuracy: 0.9897 - val_loss: 0.4040 - val_accuracy: 0.9070 - 6s/epoch - 238ms/step
# Epoch 10/30
# 25/25 - 6s - loss: 0.0433 - accuracy: 0.9845 - val_loss: 0.5534 - val_accuracy: 0.8837 - 6s/epoch - 236ms/step
# Epoch 11/30
# 25/25 - 6s - loss: 0.0620 - accuracy: 0.9793 - val_loss: 0.7510 - val_accuracy: 0.8140 - 6s/epoch - 234ms/step
# Epoch 12/30
# 25/25 - 6s - loss: 0.0964 - accuracy: 0.9793 - val_loss: 0.4068 - val_accuracy: 0.8837 - 6s/epoch - 236ms/step
# Epoch 13/30
# 25/25 - 6s - loss: 0.0500 - accuracy: 0.9793 - val_loss: 0.3979 - val_accuracy: 0.9070 - 6s/epoch - 235ms/step
# Epoch 14/30
# 25/25 - 6s - loss: 0.0814 - accuracy: 0.9767 - val_loss: 0.4376 - val_accuracy: 0.9070 - 6s/epoch - 234ms/step
# Epoch 15/30
# 25/25 - 6s - loss: 0.0735 - accuracy: 0.9767 - val_loss: 0.3933 - val_accuracy: 0.9302 - 6s/epoch - 233ms/step
# Epoch 16/30
# 25/25 - 6s - loss: 0.0471 - accuracy: 0.9767 - val_loss: 0.6501 - val_accuracy: 0.8372 - 6s/epoch - 234ms/step
# Epoch 17/30
# 25/25 - 6s - loss: 0.0246 - accuracy: 0.9897 - val_loss: 0.8369 - val_accuracy: 0.8140 - 6s/epoch - 234ms/step
# Epoch 18/30
# 25/25 - 6s - loss: 0.0494 - accuracy: 0.9922 - val_loss: 0.9219 - val_accuracy: 0.7907 - 6s/epoch - 236ms/step
# Epoch 19/30
# 25/25 - 6s - loss: 0.0728 - accuracy: 0.9871 - val_loss: 1.3859 - val_accuracy: 0.7442 - 6s/epoch - 235ms/step
# Epoch 20/30
# 25/25 - 6s - loss: 0.0467 - accuracy: 0.9819 - val_loss: 1.1325 - val_accuracy: 0.7907 - 6s/epoch - 236ms/step
# Epoch 21/30
# 25/25 - 6s - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.7118 - val_accuracy: 0.8140 - 6s/epoch - 236ms/step
# Epoch 22/30
# 25/25 - 6s - loss: 0.0371 - accuracy: 0.9897 - val_loss: 0.6988 - val_accuracy: 0.8372 - 6s/epoch - 233ms/step
# Epoch 23/30
# 25/25 - 6s - loss: 0.1006 - accuracy: 0.9638 - val_loss: 0.8748 - val_accuracy: 0.7674 - 6s/epoch - 235ms/step
# Epoch 24/30
# 25/25 - 6s - loss: 0.0750 - accuracy: 0.9819 - val_loss: 0.6717 - val_accuracy: 0.7674 - 6s/epoch - 236ms/step
# Epoch 25/30
# 25/25 - 6s - loss: 0.0401 - accuracy: 0.9845 - val_loss: 0.5516 - val_accuracy: 0.8372 - 6s/epoch - 236ms/step
# Epoch 26/30
# 25/25 - 6s - loss: 0.1276 - accuracy: 0.9742 - val_loss: 0.5037 - val_accuracy: 0.8605 - 6s/epoch - 235ms/step
# Epoch 27/30
# 25/25 - 6s - loss: 0.0344 - accuracy: 0.9897 - val_loss: 0.4580 - val_accuracy: 0.8372 - 6s/epoch - 235ms/step
# Epoch 28/30
# 25/25 - 6s - loss: 0.0268 - accuracy: 0.9845 - val_loss: 0.5900 - val_accuracy: 0.8140 - 6s/epoch - 234ms/step
# Epoch 29/30
# 25/25 - 6s - loss: 0.0386 - accuracy: 0.9922 - val_loss: 0.8672 - val_accuracy: 0.7907 - 6s/epoch - 235ms/step
# Epoch 30/30
# 25/25 - 6s - loss: 0.0386 - accuracy: 0.9948 - val_loss: 0.6350 - val_accuracy: 0.8372 - 6s/epoch - 234ms/step
# INFO:tensorflow:Assets written to: ram://a3781a0a-3c6e-4733-9e12-e7447b7d42ba/assets
# Test loss: 0.6350006461143494
# Test accuracy: 0.8372092843055725
# <PIL.Image.Image image mode=L size=92x112 at 0x7F30BE8CC090>
# <PIL.Image.Image image mode=L size=92x112 at 0x7F30BD684DD0>
# <PIL.Image.Image image mode=L size=92x112 at 0x7F30BD6841D0>
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f30be86d950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# sorin_LBP
# andreea_LBP
# alex_LBP
